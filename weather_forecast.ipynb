# %%
pip install scikit-learn==1.5.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib
import pandas as pd

# %%
raw_df = pd.read_csv('data/weatherAUS.csv')

# %%
model = joblib.load('models/aussie_rain.joblib')

# %%
if hasattr(model, 'feature_names_in_'):
    print(model.feature_names_in_)

# %%
print(type(model))
# Out:
# <class 'dict'>

# %%
print(model.keys())
# Out:
# dict_keys(['model', 'imputer', 'scaler', 'encoder', 'input_cols', 'target_col', 'numeric_cols', 'categorical_cols', 'encoded_cols'])

# %%
print("Numeric cols:", model['numeric_cols'])
print("Categorical cols:", model['categorical_cols'])
print("Input cols:", model['input_cols'])
print("Target col:", model['target_col'])
# Out:
# Numeric cols: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']
# Categorical cols: ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']
# Input cols: ['Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday']
# Target col: RainTomorrow

# %%
for col, categories in zip(model['categorical_cols'], model['encoder'].categories_):
    print(col, '->', list(categories))
# Out:
# Location -> ['Adelaide', 'Albany', 'Albury', 'AliceSprings', 'BadgerysCreek', 'Ballarat', 'Bendigo', 'Brisbane', 'Cairns', 'Canberra', 'Cobar', 'CoffsHarbour', 'Dartmoor', 'Darwin', 'GoldCoast', 'Hobart', 'Katherine', 'Launceston', 'Melbourne', 'MelbourneAirport', 'Mildura', 'Moree', 'MountGambier', 'MountGinini', 'Newcastle', 'Nhil', 'NorahHead', 'NorfolkIsland', 'Nuriootpa', 'PearceRAAF', 'Penrith', 'Perth', 'PerthAirport', 'Portland', 'Richmond', 'Sale', 'SalmonGums', 'Sydney', 'SydneyAirport', 'Townsville', 'Tuggeranong', 'Uluru', 'WaggaWagga', 'Walpole', 'Watsonia', 'Williamtown', 'Witchcliffe', 'Wollongong', 'Woomera']
# WindGustDir -> ['E', 'ENE', 'ESE', 'N', 'NE', 'NNE', 'NNW', 'NW', 'S', 'SE', 'SSE', 'SSW', 'SW', 'W', 'WNW', 'WSW', nan]
# WindDir9am -> ['E', 'ENE', 'ESE', 'N', 'NE', 'NNE', 'NNW', 'NW', 'S', 'SE', 'SSE', 'SSW', 'SW', 'W', 'WNW', 'WSW', nan]
# ...
